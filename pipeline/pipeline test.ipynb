# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from PneumBioMarker_Class import *

# %%
itemid = 904224461
test = PBM()
items = test.item_search_prepare()
test.item_search(items, itemid)
# Out:
# (array(['PRE'], dtype=object),
#  array(['Docusate Sodium', 'Docusate', 'Docusate Sodium (Liquid)',
#         'Docusate ', 'Docusate Sodiu', 'Docusat', 'Docusate Sodi',
#         'Docusate Sod', 'Docus', 'Docusate S', 'Docusa'], dtype=object))

# %%
test = PBM()
feature_name, d_df, s_df = test.absum_prepare()
top10_list = [51277, 51006, 50912, 50893, 409176230, 50882, 50983, 51003, 50862, 51274]
test.absum(top10_list, feature_name, d_df, s_df)
