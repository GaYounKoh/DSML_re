# %% [markdown]
# # loss가 가장 낮게 나올 때의 하이퍼 파라미터를 저장하는 코드
# 저장하는 이유: 매번 학습하면 시간 오래걸리니까
# <br>
# LSH 07 Best Model Saving

# %%
import numpy as np, os
import pandas as pd
import tensorflow as tf
from tqdm import tqdm

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# gpus = tf.config.experimental.list_physical_devices('GPU')
# print(gpus)
# if gpus:  # gpu가 있다면, 용량 한도를 5GB로 설정
#     tf.config.experimental.set_virtual_device_configuration(gpus[0], 
#                                                             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
#GPU 사용 설정, -1이면 CPU 사용
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
! ps
# Out:
#     PID TTY          TIME CMD
#  232850 pts/5    00:00:00 ps

# %%
# loss가 순간순간 낮아지면 그때그때의 하이퍼파라미터로 된 LSTM(모델 자체)을 저장하는 코드
# loss가 가장 낮은것만 빼고 다 지울 것. (loss는 파일확장자 바로 앞 숫자임.)


import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2]))) # 모델에는 1,2번째만 들어가니까 데이터의 shape을 바꿀 때 0번째의 크기는 상관이 없음.
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 5s 66ms/step - loss: 0.6757 - acc: 0.5984 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66548, saving model to ./model/seed42-01-0.6655.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.6691 - acc: 0.6089 - val_loss: 0.6488 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66548 to 0.64878, saving model to ./model/seed42-02-0.6488.hdf5
# Epoch 3/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.6012 - acc: 0.6711 - val_loss: 0.5525 - val_acc: 0.7342
#
# Epoch 00003: val_loss improved from 0.64878 to 0.55255, saving model to ./model/seed42-03-0.5525.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 52ms/step - loss: 0.4873 - acc: 0.7783 - val_loss: 0.5084 - val_acc: 0.7607
#
# Epoch 00004: val_loss improved from 0.55255 to 0.50836, saving model to ./model/seed42-04-0.5084.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.4161 - acc: 0.8201 - val_loss: 0.5029 - val_acc: 0.7749
#
# Epoch 00005: val_loss improved from 0.50836 to 0.50288, saving model to ./model/seed42-05-0.5029.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.3635 - acc: 0.8630 - val_loss: 0.5459 - val_acc: 0.7704
#
# Epoch 00006: val_loss did not improve from 0.50288
# Epoch 7/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3272 - acc: 0.8809 - val_loss: 0.5512 - val_acc: 0.7639
#
# Epoch 00007: val_loss did not improve from 0.50288
# Epoch 8/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3150 - acc: 0.8868 - val_loss: 0.5919 - val_acc: 0.7568
#
# Epoch 00008: val_loss did not improve from 0.50288
# Epoch 9/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2915 - acc: 0.8911 - val_loss: 0.6701 - val_acc: 0.7419
#
# Epoch 00009: val_loss did not improve from 0.50288
# Epoch 10/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2961 - acc: 0.8885 - val_loss: 0.6047 - val_acc: 0.7367
#
# Epoch 00010: val_loss did not improve from 0.50288
# Epoch 11/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2727 - acc: 0.9023 - val_loss: 0.6175 - val_acc: 0.7432
#
# Epoch 00011: val_loss did not improve from 0.50288
# Epoch 12/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2458 - acc: 0.9191 - val_loss: 0.6637 - val_acc: 0.7354
#
# Epoch 00012: val_loss did not improve from 0.50288
# Epoch 13/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2587 - acc: 0.9094 - val_loss: 0.7171 - val_acc: 0.7102
#
# Epoch 00013: val_loss did not improve from 0.50288
# Epoch 14/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3206 - acc: 0.8695 - val_loss: 0.6800 - val_acc: 0.7277
#
# Epoch 00014: val_loss did not improve from 0.50288
# Epoch 15/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2706 - acc: 0.9027 - val_loss: 0.6786 - val_acc: 0.7451
#
# Epoch 00015: val_loss did not improve from 0.50288
# Epoch 16/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2527 - acc: 0.9124 - val_loss: 0.7297 - val_acc: 0.7413
#
# Epoch 00016: val_loss did not improve from 0.50288
# Epoch 17/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2484 - acc: 0.9191 - val_loss: 0.7546 - val_acc: 0.7387
#
# Epoch 00017: val_loss did not improve from 0.50288
# Epoch 18/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2431 - acc: 0.9180 - val_loss: 0.7716 - val_acc: 0.7367
#
# Epoch 00018: val_loss did not improve from 0.50288
# Epoch 19/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2588 - acc: 0.9092 - val_loss: 0.7560 - val_acc: 0.7406
#
# Epoch 00019: val_loss did not improve from 0.50288
# Epoch 20/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2907 - acc: 0.8861 - val_loss: 0.6178 - val_acc: 0.7574
#
# Epoch 00020: val_loss did not improve from 0.50288
# Epoch 21/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2810 - acc: 0.8919 - val_loss: 0.5912 - val_acc: 0.7490
#
# Epoch 00021: val_loss did not improve from 0.50288
# Epoch 22/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2077 - acc: 0.9327 - val_loss: 0.6441 - val_acc: 0.7490
#
# Epoch 00022: val_loss did not improve from 0.50288
# Epoch 23/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1728 - acc: 0.9472 - val_loss: 0.7000 - val_acc: 0.7536
#
# Epoch 00023: val_loss did not improve from 0.50288
# Epoch 24/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1576 - acc: 0.9547 - val_loss: 0.7394 - val_acc: 0.7510
#
# Epoch 00024: val_loss did not improve from 0.50288
# Epoch 25/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1439 - acc: 0.9614 - val_loss: 0.7716 - val_acc: 0.7484
#
# Epoch 00025: val_loss did not improve from 0.50288
# Epoch 26/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1331 - acc: 0.9648 - val_loss: 0.7926 - val_acc: 0.7439
#
# Epoch 00026: val_loss did not improve from 0.50288
# Epoch 27/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1209 - acc: 0.9696 - val_loss: 0.8208 - val_acc: 0.7464
#
# Epoch 00027: val_loss did not improve from 0.50288
# Epoch 28/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1139 - acc: 0.9707 - val_loss: 0.8475 - val_acc: 0.7471
#
# Epoch 00028: val_loss did not improve from 0.50288
# Epoch 29/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1067 - acc: 0.9743 - val_loss: 0.8772 - val_acc: 0.7458
#
# Epoch 00029: val_loss did not improve from 0.50288
# Epoch 30/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1034 - acc: 0.9748 - val_loss: 0.8983 - val_acc: 0.7477
#
# Epoch 00030: val_loss did not improve from 0.50288
# Epoch 31/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0985 - acc: 0.9771 - val_loss: 0.9125 - val_acc: 0.7432
#
# Epoch 00031: val_loss did not improve from 0.50288
# Epoch 32/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0959 - acc: 0.9784 - val_loss: 0.9344 - val_acc: 0.7432
#
# Epoch 00032: val_loss did not improve from 0.50288
# Epoch 33/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0946 - acc: 0.9795 - val_loss: 0.9395 - val_acc: 0.7439
#
# Epoch 00033: val_loss did not improve from 0.50288
# Epoch 34/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0926 - acc: 0.9780 - val_loss: 0.9559 - val_acc: 0.7413
#
# Epoch 00034: val_loss did not improve from 0.50288
# Epoch 35/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0871 - acc: 0.9808 - val_loss: 0.9668 - val_acc: 0.7439
#
# Epoch 00035: val_loss did not improve from 0.50288
# Epoch 36/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.0870 - acc: 0.9812 - val_loss: 0.9781 - val_acc: 0.7419
#
# Epoch 00036: val_loss did not improve from 0.50288
# Epoch 37/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0806 - acc: 0.9827 - val_loss: 0.9923 - val_acc: 0.7387
#
# Epoch 00037: val_loss did not improve from 0.50288
# Epoch 38/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0787 - acc: 0.9832 - val_loss: 1.0056 - val_acc: 0.7393
#
# Epoch 00038: val_loss did not improve from 0.50288
# Epoch 39/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0833 - acc: 0.9804 - val_loss: 1.0057 - val_acc: 0.7400
#
# Epoch 00039: val_loss did not improve from 0.50288
# Epoch 40/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0822 - acc: 0.9799 - val_loss: 1.0322 - val_acc: 0.7309
#
# Epoch 00040: val_loss did not improve from 0.50288
# Epoch 41/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0962 - acc: 0.9771 - val_loss: 1.0206 - val_acc: 0.7329
#
# Epoch 00041: val_loss did not improve from 0.50288
# Epoch 42/500
# 37/37 [==============================] - 2s 52ms/step - loss: 0.1082 - acc: 0.9687 - val_loss: 0.9717 - val_acc: 0.7348
#
# Epoch 00042: val_loss did not improve from 0.50288
# Epoch 43/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1589 - acc: 0.9493 - val_loss: 0.9813 - val_acc: 0.7277
#
# Epoch 00043: val_loss did not improve from 0.50288
# Epoch 44/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1265 - acc: 0.9631 - val_loss: 0.8770 - val_acc: 0.7393
#
# Epoch 00044: val_loss did not improve from 0.50288
# Epoch 45/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0882 - acc: 0.9793 - val_loss: 0.9463 - val_acc: 0.7329
#
# Epoch 00045: val_loss did not improve from 0.50288
# Epoch 46/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0772 - acc: 0.9830 - val_loss: 0.9864 - val_acc: 0.7354
#
# Epoch 00046: val_loss did not improve from 0.50288
# Epoch 47/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0676 - acc: 0.9853 - val_loss: 1.0200 - val_acc: 0.7354
#
# Epoch 00047: val_loss did not improve from 0.50288
# Epoch 48/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0651 - acc: 0.9853 - val_loss: 1.0468 - val_acc: 0.7322
#
# Epoch 00048: val_loss did not improve from 0.50288
# Epoch 49/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0634 - acc: 0.9866 - val_loss: 1.0628 - val_acc: 0.7309
#
# Epoch 00049: val_loss did not improve from 0.50288
# Epoch 50/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0625 - acc: 0.9871 - val_loss: 1.0844 - val_acc: 0.7296
#
# Epoch 00050: val_loss did not improve from 0.50288
# Epoch 51/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0592 - acc: 0.9879 - val_loss: 1.0997 - val_acc: 0.7329
#
# Epoch 00051: val_loss did not improve from 0.50288
# Epoch 52/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0585 - acc: 0.9877 - val_loss: 1.1177 - val_acc: 0.7303
#
# Epoch 00052: val_loss did not improve from 0.50288
# Epoch 53/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0586 - acc: 0.9871 - val_loss: 1.1315 - val_acc: 0.7303
#
# Epoch 00053: val_loss did not improve from 0.50288
# Epoch 54/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0540 - acc: 0.9892 - val_loss: 1.1507 - val_acc: 0.7264
#
# Epoch 00054: val_loss did not improve from 0.50288
# Epoch 55/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0558 - acc: 0.9884 - val_loss: 1.1573 - val_acc: 0.7303
# Restoring model weights from the end of the best epoch.
#
# Epoch 00055: val_loss did not improve from 0.50288
# Epoch 00055: early stopping

# %%
# best model의 정확도를 확인하는 코드
from keras.models import load_model
best_model = load_model('./model/seed42-05-0.5021.hdf5') 

dic_42={}
for seed in range(0, 50):
    random.seed(seed) # random.seed는 seed setting을 위한 함수임.

    x = np.load('/project/LSH/x_(7727,10,4068).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# Using TensorFlow backend.
# 정확도 :0.8194174757281554, seed_num = 0
# 정확도 :0.8362459546925566, seed_num = 1
# 정확도 :0.8207119741100324, seed_num = 2
# 정확도 :0.8388349514563107, seed_num = 3
# 정확도 :0.8252427184466019, seed_num = 4
# 정확도 :0.8401294498381877, seed_num = 5
# 정확도 :0.8103559870550162, seed_num = 6
# 정확도 :0.8155339805825242, seed_num = 7
# 정확도 :0.827831715210356, seed_num = 8
# 정확도 :0.8317152103559871, seed_num = 9
# 정확도 :0.8265372168284789, seed_num = 10
# 정확도 :0.8310679611650486, seed_num = 11
# 정확도 :0.8349514563106796, seed_num = 12
# 정확도 :0.8343042071197411, seed_num = 13
# 정확도 :0.8381877022653722, seed_num = 14
# 정확도 :0.8336569579288026, seed_num = 15
# 정확도 :0.8330097087378641, seed_num = 16
# 정확도 :0.8174757281553398, seed_num = 17
# 정확도 :0.8271844660194175, seed_num = 18
# 정확도 :0.8388349514563107, seed_num = 19
# 정확도 :0.8284789644012945, seed_num = 20
# 정확도 :0.8142394822006472, seed_num = 21
# 정확도 :0.8226537216828479, seed_num = 22
# 정확도 :0.8090614886731392, seed_num = 23
# 정확도 :0.8317152103559871, seed_num = 24
# 정확도 :0.8466019417475729, seed_num = 25
# 정확도 :0.8245954692556634, seed_num = 26
# 정확도 :0.8103559870550162, seed_num = 27
# 정확도 :0.8330097087378641, seed_num = 28
# 정확도 :0.8207119741100324, seed_num = 29
# 정확도 :0.8446601941747572, seed_num = 30
# 정확도 :0.8200647249190939, seed_num = 31
# 정확도 :0.8110032362459547, seed_num = 32
# 정확도 :0.8252427184466019, seed_num = 33
# 정확도 :0.8375404530744337, seed_num = 34
# 정확도 :0.8220064724919094, seed_num = 35
# 정확도 :0.8381877022653722, seed_num = 36
# 정확도 :0.8459546925566344, seed_num = 37
# 정확도 :0.8110032362459547, seed_num = 38
# 정확도 :0.8297734627831715, seed_num = 39
# 정확도 :0.8271844660194175, seed_num = 40
# 정확도 :0.8226537216828479, seed_num = 41
# 정확도 :0.7779935275080906, seed_num = 42
# 정확도 :0.8388349514563107, seed_num = 43
# 정확도 :0.8226537216828479, seed_num = 44
# 정확도 :0.8284789644012945, seed_num = 45
# 정확도 :0.8155339805825242, seed_num = 46
# 정확도 :0.8362459546925566, seed_num = 47
# 정확도 :0.8362459546925566, seed_num = 48
# 정확도 :0.8226537216828479, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 82.6
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.826731
# dtype: float64

# %% [markdown]
# # seed별 best model 저장
# seed 수동으로 바꿔줄 것

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


import random
# ----------------------
seed_num = 50
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 50 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'seed'f'{seed_num}''-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)

# %%
# ----------------------------
seed_num = 50
# ----------------------------

from keras.models import load_model
best_model = load_model('./model/seed50-04-0.5157.hdf5') # 수동으로 확인

dic={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4068).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
    
df = pd.DataFrame.from_dict(dic, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
